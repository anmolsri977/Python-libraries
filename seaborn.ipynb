# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.displot([0,1,2,3,4,5])
plt.show()
data=sns.load_dataset("iris")
sns.lineplot(x="sepal_length",y="sepal_width",data=data)
sns.pairplot(data=data,hue='species')
plt.show()

# %%
data=sns.load_dataset("iris")
sns.kdeplot(x="sepal_length",y="sepal_width",data=data)

plt.show()

# %%
data=sns.load_dataset("iris")
sns.boxplot(x="species",y="sepal_width",data=data)

plt.show()

# %%
data=sns.load_dataset("iris")
sns.stripplot(x="species",y="sepal_width",data=data)

plt.show()

# %%
import os
print(os.listdir('/kaggle/input/seaborn'))
import pandas as pd
df=pd.read_csv('/Kaggle/input/irisdata/iris.csv')
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x="sepal_length",y="sepal_width",data=df)
plt.show();

# %% [markdown]
# paste this in kaggle (already downloaded iris.csv file from github)

# %%
#load tips dataset
tips_df=sns.load_dataset('tips')
sns.violinplot(x='day',y='tip',hue='time',data=tips_df,split=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-851941474.py in <cell line: 0>()
#       1 #load tips dataset
# ----> 2 tips_df=sns.load_dataset('tips')
#       3 sns.violinplot(x='day',y='tip',hue='time',data=tips_df,split=True)
#
# NameError: name 'sns' is not defined

# %%
import matplotlib.pyplot as plt
data=sns.load_dataset("tips")
#correlation btw diff parameters
tc=data.corr()
sns.heatmap(tc)
plt.show()
